# %% [markdown]
# # NGSIM.jl

# %%
using NGSIM
using AutomotiveDrivingModels
using AutoViz

# %%
render(ROADWAY_80)
# Out:
# Cairo.CairoSurface{UInt32}(Ptr{Void} @0x000000000466a2c0, 1000.0, 600.0, #undef)

# %%
render(ROADWAY_101)
# Out:
# Cairo.CairoSurface{UInt32}(Ptr{Void} @0x000000000318cf40, 1000.0, 600.0, #undef)

# %%
render(ROADWAY_101, cam=StaticCamera(VecE2(1966600, 570700), 10.0))
# Out:
# Cairo.CairoSurface{UInt32}(Ptr{Void} @0x00000000046efc60, 1000.0, 600.0, #undef)

# %%
td1 = load_trajdata(1)
scene = get!(Scene(500), td1, 1000)
render(scene, ROADWAY_101)
# Out:
# Cairo.CairoSurface{UInt32}(Ptr{Void} @0x0000000003d2e7a0, 1000.0, 600.0, #undef)

# %%
# using Interact
# scene = Scene(500)
# @manipulate for i in 1000:2000
#     render(get!(scene, td1, i), ROADWAY_101, cam=StaticCamera(VecE2(1966400, 570900), 5.0))
# end

# %%
scene[1].def
# Out:
# BoundingBoxDef(CAR, 5.639, 2.408)

# %%
fieldnames(scene[1].state)
# Out:
# 4-element Array{Symbol,1}:
#  :posG
#  :posF
#  :tag
#  :v

# %%
fieldnames(scene[1].state.posG)
# Out:
# 3-element Array{Symbol,1}:
#  :x
#  :y
#  :θ

# %%
fieldnames(scene[1].state.posF)
# Out:
# 3-element Array{Symbol,1}:
#  :s
#  :t
#  :ϕ
