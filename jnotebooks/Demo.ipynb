# %% [markdown]
# # NGSIM.jl

# %%
using NGSIM
using AutomotiveDrivingModels
using AutoViz

# %%
render(ROADWAY_80)
# Out:
# Cairo.CairoSurfaceBase{UInt32}(Ptr{Nothing} @0x0000000015550950, 1000.0, 600.0)

# %%
render(ROADWAY_101)
# Out:
# Cairo.CairoSurfaceBase{UInt32}(Ptr{Nothing} @0x000000000ab52fd0, 1000.0, 600.0)

# %%
render(ROADWAY_101, cam=StaticCamera(VecE2(1966600, 570700), 10.0))
# Out:
# Cairo.CairoSurfaceBase{UInt32}(Ptr{Nothing} @0x000000000ab537a0, 1000.0, 600.0)

# %%
# the following test requires downloading the dataset
# td1 = load_trajdata(1)
# scene = get!(Scene(500), td1, 1000)
# render(scene, ROADWAY_101)

# %%
# using Interact
# scene = Scene(500)
# @manipulate for i in 1000:2000
#     render(get!(scene, td1, i), ROADWAY_101, cam=StaticCamera(VecE2(1966400, 570900), 5.0))
# end
